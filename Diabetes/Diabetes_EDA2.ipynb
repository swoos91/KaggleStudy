# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import missingno as msno

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn')
sns.set(font_scale=2.5)
# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/pima-indians-diabetes-database/diabetes.csv

# %%
df = pd.read_csv('/kaggle/input/pima-indians-diabetes-database/diabetes.csv')
df.shape
# Out:
# (768, 9)

# %%
display(df.head())
display(df.info())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
# ...

# %%
df_null = df.isnull().sum()
display(df_null)
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
display(df.describe())
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
feature_colnames = df.columns[:-1].tolist()

# %%
cols = feature_colnames[1:]
df_null = df[cols].replace(0, np.nan)
df_null = df_null.isnull()
df_null.sum().plot.barh()

# %%
plt.figure(figsize=(15,4))
sns.heatmap(df_null, cmap='Greys_r')

# %%
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df['Outcome'].value_counts(normalize=True)
# Out:
# 0    0.651042
# 1    0.348958
# Name: Outcome, dtype: float64

# %%
df_po = df.groupby(['Pregnancies'])['Outcome'].agg(['mean', 'count']).reset_index()
df_po
# Out:
#     Pregnancies      mean  count
# 0             0  0.342342    111
# 1             1  0.214815    135
# 2             2  0.184466    103
# 3             3  0.360000     75
# 4             4  0.338235     68
# 5             5  0.368421     57
# 6             6  0.320000     50
# 7             7  0.555556     45
# 8             8  0.578947     38
# 9             9  0.642857     28
# 10           10  0.416667     24
# 11           11  0.636364     11
# 12           12  0.444444      9
# 13           13  0.500000     10
# 14           14  1.000000      2
# 15           15  1.000000      1
# 16           17  1.000000      1

# %%
df_po.plot()

# %%
plt.figure(figsize=(15,4))
df_po['mean'].plot.bar(rot=0)

# %%
f,ax = plt.subplots(2,1, figsize=(10,15))
sns.countplot(data=df, x='Outcome', ax=ax[0])
sns.countplot(data=df, x='Pregnancies', hue='Outcome',ax=ax[1])
plt.tight_layout()

# %%
df['Pregnancies_high'] = df['Pregnancies'] > 6
df[['Pregnancies', 'Pregnancies_high']].head()
# Out:
#    Pregnancies  Pregnancies_high
# 0            6             False
# 1            1             False
# 2            8              True
# 3            1             False
# 4            0             False

# %%
sns.countplot(data=df, x='Pregnancies_high', hue='Outcome')

# %%
# y축 -> mean 값, 세로막대(검은색): 부트스트랩 95% 신뢰구간
f, ax = plt.subplots(3,1, figsize=(10, 20))
sns.barplot(data=df, x='Outcome', y='BMI', ax=ax[0])
sns.barplot(data=df, x='Outcome', y='Glucose', ax=ax[1])
sns.barplot(data=df, x='Outcome', y='Insulin', ax=ax[2])

plt.tight_layout()

# %%
f, ax = plt.subplots(4,1, figsize=(15, 20))
sns.barplot(data=df, x="Pregnancies", y='Outcome', ax=ax[0])
sns.barplot(data=df, x="Pregnancies", y='Glucose', hue='Outcome', ax=ax[1])
ax[1].legend(bbox_to_anchor=(1.05,1))
sns.barplot(data=df, x="Pregnancies", y='BMI', hue='Outcome', ax=ax[2])
ax[2].legend(bbox_to_anchor=(1.05,1))
sns.barplot(data=df[ df['Insulin'] > 0 ], x="Pregnancies", y='Insulin', hue='Outcome', ax=ax[3])

plt.tight_layout()

# %%
plt.figure(figsize=(15,4))
sns.boxplot(data=df[ df['Insulin'] > 0 ], x='Pregnancies', y='Insulin', hue='Outcome')

# %%
plt.figure(figsize=(15,4))
sns.violinplot(data=df[ df['Insulin'] > 0 ], x='Pregnancies', y='Insulin', hue='Outcome', split=True)
plt.legend(bbox_to_anchor=(1.2,1))

# %%
plt.figure(figsize=(15,4))
sns.swarmplot(data=df[ df['Insulin'] > 0 ], x='Pregnancies', y='Insulin', hue='Outcome')

# %% [markdown]
# # Distplot
# - 한 개의 수치형 변수를 표현할 때 주로 사용 (cf. categorical variable은 countplot을 주로 사용)
# - KDE: Kernel Density Estimation의 약자로, kernel function과 bandwidth parameter를 이용해 R.V.의 prob. density를 추정함.
# - Kernel function: Origin을 중심으로 대칭이며, 적분값이 1인 non-negative한 함수를 일컫는다. (Normal, Uniform...)

# %%
df_0 = df[df['Outcome'] == 0]
df_1 = df[df['Outcome'] == 1]
df_0.shape, df_1.shape
# Out:
# ((500, 10), (268, 10))

# %%
plt.figure(figsize=(15,8))
sns.distplot( df_0['Pregnancies'] )
sns.distplot( df_1['Pregnancies'] )

# %%
plt.figure(figsize=(15,8))
sns.distplot(df_0['Age'])
sns.distplot(df_1['Age'])

# %% [markdown]
# ### Subplot 만들기

# %%
df['Pregnancies_high'] = df['Pregnancies_high'].astype(int)
h = df.hist(figsize=(15,15), bins=20)
plt.tight_layout()

# %%
cols = df.columns[:-1].tolist()

# %%
f, ax = plt.subplots( nrows=3, ncols=3, figsize=(15, 15) )

for i, col_name in enumerate(cols):
    row = i // 3
    col = i % 3
    print(i, col_name, row)
    sns.distplot(df[col_name], ax=ax[row][col])

# sns.distplot( df['Outcome'], ax=ax[0][0] )
plt.tight_layout()
# Out:
# 0 Pregnancies 0
# 1 Glucose 0
# 2 BloodPressure 0
# 3 SkinThickness 1
# 4 Insulin 1
# 5 BMI 1
# 6 DiabetesPedigreeFunction 2
# 7 Age 2
# 8 Outcome 2

# %%
f, ax = plt.subplots( nrows=4, ncols=2, figsize=(15, 15) )

for i, col_name in enumerate(cols[:-1]):
    row = i // 2
    col = i % 2
    print(i, col_name, row)
    sns.distplot(df_0[col_name], ax=ax[row][col])
    sns.distplot(df_1[col_name], ax=ax[row][col])

# sns.distplot( df['Outcome'], ax=ax[0][0] )
plt.tight_layout()
# Out:
# 0 Pregnancies 0
# 1 Glucose 0
# 2 BloodPressure 1
# 3 SkinThickness 1
# 4 Insulin 2
# 5 BMI 2
# 6 DiabetesPedigreeFunction 3
# 7 Age 3

# %%
f, ax = plt.subplots( nrows=4, ncols=2, figsize=(15, 25) )

for i, col_name in enumerate(cols[:-1]):
    row = i // 2
    col = i % 2
    print(i, col_name, row)
    sns.violinplot(data = df, x='Outcome',y=col_name, ax=ax[row][col])

plt.tight_layout()
# Out:
# 0 Pregnancies 0
# 1 Glucose 0
# 2 BloodPressure 1
# 3 SkinThickness 1
# 4 Insulin 2
# 5 BMI 2
# 6 DiabetesPedigreeFunction 3
# 7 Age 3

# %%
# Glucose(포도당 수치)와 Insulin의 상관관계 확인
sns.regplot(data = df, x='Glucose', y='Insulin')

# %%
# Glucose(포도당 수치)와 Insulin의 Outcome에 따른 상관관계 확인
sns.lmplot(data = df, x='Glucose', y='Insulin', hue='Outcome', height=7, aspect=1.6)

# %%
plt.figure(figsize=(15, 20))
sns.lmplot(data = df[df['Insulin'] > 0], x='Glucose', y='Insulin', hue='Outcome', height=7, aspect=1.6)

# %%
sns.pairplot(df)

# %%
g = sns.PairGrid(df, hue='Outcome', height=3, aspect=1.3)
g.map(plt.scatter)

# %%
# Coefficient

df_corr = df.corr()
df_corr.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_58631888_ece3_11ea_bf27_0242ac130202row0_col0,#T_58631888_ece3_11ea_bf27_0242ac130202row1_col1,#T_58631888_ece3_11ea_bf27_0242ac130202row2_col2,#T_58631888_ece3_11ea_bf27_0242ac130202row3_col3,#T_58631888_ece3_11ea_bf27_0242ac130202row4_col4,#T_58631888_ece3_11ea_bf27_0242ac130202row5_col5,#T_58631888_ece3_11ea_bf27_0242ac130202row6_col6,#T_58631888_ece3_11ea_bf27_0242ac130202row7_col7,#T_58631888_ece3_11ea_bf27_0242ac130202row8_col8,#T_58631888_ece3_11ea_bf27_0242ac130202row9_col9{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_58631888_ece3_11ea_bf27_0242ac130202row0_col1,#T_58631888_ece3_11ea_bf27_0242ac130202row9_col3{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_58631888_ece3_11ea_bf27_0242ac130202row0_col2,#T_58631888_ece3_11ea_bf27_0242ac130202row2_col1,#T_58631888_ece3_11ea_bf27_0242ac130202row9_col1{
#             background-color:  #f0eaf4;
# ...

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(df_corr, annot=True, vmax=1, vmin=-1, cmap='coolwarm')

# %%
df_matrix = df.iloc[:, :-2].replace(0, np.nan)
df_matrix['Outcome'] = df['Outcome']
df_matrix_corr = df_matrix.corr()
plt.figure(figsize=(20, 10))
sns.heatmap(df_matrix_corr, annot=True, vmax=1, vmin=-1, cmap='coolwarm')

# %%
df_matrix_corr['Outcome']
# Out:
# Pregnancies                 0.268218
# Glucose                     0.494650
# BloodPressure               0.170589
# SkinThickness               0.259491
# Insulin                     0.303454
# BMI                         0.313680
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %%
sns.regplot(data = df_matrix, x='Insulin', y='Glucose')

# %%
sns.regplot(data=df_matrix, x='Age', y='Pregnancies')

# %%
# sns.lmplot(data=df_matrix, x='Age', y='Pregnancies', hue='Outcome')
sns.lmplot(data=df_matrix, x='Age', y='Pregnancies', hue='Outcome', col='Outcome')
